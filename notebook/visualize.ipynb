# %%
import pandas as pd
from tqdm import tqdm

# %%
df = pd.read_json('../data/qa_dataset.json')
df
# Out:
#                                                 question  \
# 0                         Đất nước nào không có quân đội
# 1                               Núi nào cao nhất châu âu
# 2      Thành phố nào là thủ phủ của Ai Cập trong đế q...
# 3      Ai là người đứng đầu trong cuộc chống lại chín...
# 4            Nền văn hoá Phục Hưng bắt nguồn từ nước nào
# ...                                                  ...
# 26094    Là cha giải tội của Giáo hoàng là một Giám mục?
# 26095        Những tòa nhà tổ chức Viện Milton Friedman?
# 26096  Thực thể nào liên quan đến các vấn đề nhân viê...
# 26097        Thành viên của các ủy ban phản ánh điều gì?
# 26098    Người Norman kết hợp với văn hóa nào ở Ireland?
#
#                                                  context  \
# 0      có 23 quốc gia không có lực lượng quân đội, ba...
# 1      Đỉnh núi nằm ở phần trung tâm của dãy núi Đại ...
# 2      Lịch sử . Ai Cập bị La Mã chiếm năm 30 TCN , v...
# ...

# %% [markdown]
# ### EDA
